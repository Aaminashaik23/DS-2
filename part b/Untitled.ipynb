# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../diabetes.csv')

# %%
bmi_98 = data["BMI"].quantile(0.98)


sample = data.sample(n=100)
sample_bmi_98 = sample["BMI"].quantile(0.98)

# %%
plt.hist(data["BMI"], bins=20)
plt.axvline(x=pop_bmi_98, color='r', linestyle='--')
plt.title("Histogram of BMI for the Population")
plt.xlabel("BMI")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(sample["BMI"], bins=20)
plt.axvline(x=sample_bmi_98, color='r', linestyle='--')
plt.title("Histogram of BMI for the Sample")
plt.xlabel("BMI")
plt.ylabel("Frequency")
plt.show()

# %%
print("98th percentile of BMI for the population:", bmi_98)
print("98th percentile of BMI for the sample:", sample_bmi_98)
# Out:
# 98th percentile of BMI for the population: 47.52599999999996
# 98th percentile of BMI for the sample: 46.233999999999995
